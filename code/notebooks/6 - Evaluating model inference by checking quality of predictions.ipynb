# %%
# %reload_ext autoreload
# %autoreload 2
from file_exchange import model
import numpy as np
import pandas as pd

# %%
N_USERS = 100
OBSERVATIONS_LENGTH = 100
PREDICTIONS_LENGTH = 10

# %%
users = [None] * N_USERS
COLUMNS = ['user', 'device', 'state', 't', 'p', 'infered']
predictions = pd.DataFrame(columns=COLUMNS)
for user_id in range(N_USERS):
    m = model.get_random()
    _, observations  = m.sample(length=OBSERVATIONS_LENGTH)
    infered_m = model.get_default(m.observations).fit(observations)
    
#     predictions = np.empty((m.n_obs, PREDICTIONS_LENGTH, m.n_states), dtype=np.float64)
#     infered_predictions = \
#         np.empty((m.n_obs, PREDICTIONS_LENGTH, m.n_states), dtype=np.float64)
    for obs_id in range(m.n_obs):
        prediction = m.predict(PREDICTIONS_LENGTH, obs_id)
        infered_prediction = infered_m.predict(PREDICTIONS_LENGTH, obs_id)
#         print(prediction.shape)
#         print(prediction)
        
        predictions = predictions.append(
            pd.concat([
                    pd.DataFrame(
                        [[user_id, obs_id, s, t, prediction[t, s], False]], 
                        columns=COLUMNS)
                for t in range(PREDICTIONS_LENGTH)
                for s in range(m.n_states)
            ], ignore_index=True), ignore_index=True)
        predictions = predictions.append(
            pd.concat([
                    pd.DataFrame(
                        [[user_id, obs_id, s, t, infered_prediction[t, s], True]], 
                        columns=COLUMNS)
                for t in range(PREDICTIONS_LENGTH)
                for s in range(m.n_states)
            ], ignore_index=True))
            
predictions['t'] = predictions['t']+1  
predictions
# Out:
#    user device state  t         p infered
# 0     0      0     0  0  0.846146   False
# 1     0      0     1  0  0.863772   False
# 2     0      0     2  0  0.859094   False
# 3     0      0     0  1  0.853196   False
# 4     0      0     1  1  0.859311   False
# 5     0      0     2  1  0.860965   False
# 6     0      0     0  2  0.855642   False
# 7     0      0     1  2  0.858419   False
# 8     0      0     2  2  0.860303   False
# 9     0      0     0  3  0.856753   False
# 10    0      0     1  3  0.858240   False
# 11    0      0     2  3  0.859549   False
# 12    0      0     0  4  0.857348   False
# 13    0      0     1  4  0.858204   False
# 14    0      0     2  4  0.859026   False
# 15    0      0     0  5  0.857690   False
# 16    0      0     1  5  0.858197   False
# 17    0      0     2  5  0.858697   False
# 18    0      0     0  6  0.857893   False
# 19    0      0     1  6  0.858196   False
# 20    0      0     2  6  0.858497   False
# 21    0      0     0  7  0.858014   False
# 22    0      0     1  7  0.858196   False
# 23    0      0     2  7  0.858377   False
# 24    0      0     0  8  0.858087   False
# 25    0      0     1  8  0.858196   False
# 26    0      0     2  8  0.858304   False
# 27    0      0     0  9  0.858130   False
# 28    0      0     1  9  0.858196   False
# 29    0      0     2  9  0.858261   False
# ..  ...    ...   ... ..       ...     ...
# 0    99      8     0  0  0.000000   False
# 1    99      8     1  0  0.089462   False
# 2    99      8     2  0  0.268386   False
# 3    99      8     0  1  0.035785   False
# 4    99      8     1  1  0.107354   False
# 5    99      8     2  1  0.196816   False
# 6    99      8     0  2  0.064413   False
# 7    99      8     1  2  0.110933   False
# 8    99      8     2  2  0.161032   False
# 9    99      8     0  3  0.083021   False
# 10   99      8     1  3  0.111649   False
# 11   99      8     2  3  0.140992   False
# 12   99      8     0  4  0.094472   False
# 13   99      8     1  4  0.111792   False
# 14   99      8     2  4  0.129255   False
# 15   99      8     0  5  0.101400   False
# 16   99      8     1  5  0.111820   False
# 17   99      8     2  5  0.122269   False
# 18   99      8     0  6  0.105568   False
# 19   99      8     1  6  0.111826   False
# 20   99      8     2  6  0.118090   False
# 21   99      8     0  7  0.108071   False
# 22   99      8     1  7  0.111827   False
# 23   99      8     2  7  0.115584   False
# 24   99      8     0  8  0.109574   False
# 25   99      8     1  8  0.111827   False
# 26   99      8     2  8  0.114081   False
# 27   99      8     0  9  0.110475   False
# 28   99      8     1  9  0.111827   False
# 29   99      8     2  9  0.113180   False
#
# [54000 rows x 6 columns]

# %%
predictions
# Out:
#    user device state   t         p infered
# 0     0      0     0   1  0.846146   False
# 1     0      0     1   1  0.863772   False
# 2     0      0     2   1  0.859094   False
# 3     0      0     0   2  0.853196   False
# 4     0      0     1   2  0.859311   False
# 5     0      0     2   2  0.860965   False
# 6     0      0     0   3  0.855642   False
# 7     0      0     1   3  0.858419   False
# 8     0      0     2   3  0.860303   False
# 9     0      0     0   4  0.856753   False
# 10    0      0     1   4  0.858240   False
# 11    0      0     2   4  0.859549   False
# 12    0      0     0   5  0.857348   False
# 13    0      0     1   5  0.858204   False
# 14    0      0     2   5  0.859026   False
# 15    0      0     0   6  0.857690   False
# 16    0      0     1   6  0.858197   False
# 17    0      0     2   6  0.858697   False
# 18    0      0     0   7  0.857893   False
# 19    0      0     1   7  0.858196   False
# 20    0      0     2   7  0.858497   False
# 21    0      0     0   8  0.858014   False
# 22    0      0     1   8  0.858196   False
# 23    0      0     2   8  0.858377   False
# 24    0      0     0   9  0.858087   False
# 25    0      0     1   9  0.858196   False
# 26    0      0     2   9  0.858304   False
# 27    0      0     0  10  0.858130   False
# 28    0      0     1  10  0.858196   False
# 29    0      0     2  10  0.858261   False
# ..  ...    ...   ...  ..       ...     ...
# 0    99      8     0   1  0.000000   False
# 1    99      8     1   1  0.089462   False
# 2    99      8     2   1  0.268386   False
# 3    99      8     0   2  0.035785   False
# 4    99      8     1   2  0.107354   False
# 5    99      8     2   2  0.196816   False
# 6    99      8     0   3  0.064413   False
# 7    99      8     1   3  0.110933   False
# 8    99      8     2   3  0.161032   False
# 9    99      8     0   4  0.083021   False
# 10   99      8     1   4  0.111649   False
# 11   99      8     2   4  0.140992   False
# 12   99      8     0   5  0.094472   False
# 13   99      8     1   5  0.111792   False
# 14   99      8     2   5  0.129255   False
# 15   99      8     0   6  0.101400   False
# 16   99      8     1   6  0.111820   False
# 17   99      8     2   6  0.122269   False
# 18   99      8     0   7  0.105568   False
# 19   99      8     1   7  0.111826   False
# 20   99      8     2   7  0.118090   False
# 21   99      8     0   8  0.108071   False
# 22   99      8     1   8  0.111827   False
# 23   99      8     2   8  0.115584   False
# 24   99      8     0   9  0.109574   False
# 25   99      8     1   9  0.111827   False
# 26   99      8     2   9  0.114081   False
# 27   99      8     0  10  0.110475   False
# 28   99      8     1  10  0.111827   False
# 29   99      8     2  10  0.113180   False
#
# [54000 rows x 6 columns]

# %%
df = pd.DataFrame(columns=['v', 't'])
for i in range(a.shape[1]):
    df = df.concat([
        pd.DataFrame([v, t], columns=['v', 't']) for t, v in enumerate(a[:,i])
    ], ignore_index=True)
    
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-fa1aa4924ce6> in <module>()
#       1 df = pd.DataFrame(columns=['v', 't'])
#       2 for i in range(a.shape[1]):
# ----> 3     df = df.concat([
#       4         pd.DataFrame([v, t], columns=['v', 't']) for t, v in enumerate(a[:,i])
#       5     ], ignore_index=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
df = pd.concat([
        pd.DataFrame([[v, t, s]], columns=['v', 't', 's']) 
    for s in range(a.shape[0])
    for i in range(a.shape[2])
    for t, v in enumerate(a[s, :,i])
    ], ignore_index=True)
df
# Out:
#     v  t  s
# 0   1  0  0
# 1   3  1  0
# 2   5  2  0
# 3   2  0  0
# 4   4  1  0
# 5   6  2  0
# 6   1  0  1
# 7   3  1  1
# 8   5  2  1
# 9   2  0  1
# 10  4  1  1
# 11  6  2  1
